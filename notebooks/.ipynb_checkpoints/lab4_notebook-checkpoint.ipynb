# %% [markdown]
# ## CZ3006 Lab 4 - Analyzing Network Traffic Log Data using Python
#
# Conduct basic analysis of the given SFLow traffic data log and generate the following information:
#
# * Top 5 talkers (Sending nodes)
# * Top 5 listeners (Receiving nodes)
# * Top 5 applications
# * Traffic Intensity
# * Proportion of TCP and UDP packets
# * Top 5 communication pairs (optional)
# * Visualizing the communication between different IP hosts (Optional)
#
# Currently experimenting via Notebook, eventually will convert into a Python script

# %% [markdown]
# ### Import libraries and load dataset

# %%
import pandas as pd
import requests
import math

n = 5
ip_api_url = 'http://ip-api.com/json'
dataset_url = '../test_SFLow_data.csv'

traffic_data_cols = ['type', 'sf_agent_address', 'input_port', 'output_port', 'src_MAC', 'dst_MAC', 'ethernet_type',
'in_vlan', 'out_vlan', 'src_IP', 'dst_IP', 'IP_protocol', 'ip_tos', 'ip_ttl', 'src_port', 'dst_port',
'tcp_flags', 'packet_size', 'IP_size', 'sampling_rate']

# %%
traffic_df = pd.read_csv(
    dataset_url,
    index_col=False,
    names=traffic_data_cols
)

total_rows = traffic_df.shape[0]
print(f'Traffic Log has {total_rows} rows and {traffic_df.shape[1]} columns')
traffic_df.head(10)
# Out:
# Traffic Log has 1200 rows and 20 columns
#    type sf_agent_address  input_port  output_port       src_MAC       dst_MAC  \
# 0  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 1  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 2  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 3  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 4  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 5  FLOW      aa.aa.aa.aa         258           20  204e71cf1b0f  002438aa0a00
# 6  FLOW      aa.aa.aa.aa         200          147  80711fc76001  f4e9d4a46432
# 7  FLOW      aa.aa.aa.aa         199            3  544b8cf9a7df  00235ed9b680
# 8  FLOW      aa.aa.aa.aa         200            3  80711fc76001  00235ed9b680
# 9  FLOW      aa.aa.aa.aa         193          131  0031466b23cf  00a742233e9e
#
#   ethernet_type  in_vlan  out_vlan          src_IP          dst_IP  \
# 0        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 1        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 2        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 3        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 4        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 5        0x0800   3012.0      3012    152.3.219.19    198.71.44.98
# 6        0x0800    280.0       900    203.185.93.2    203.30.39.13
# 7        0x0800    600.0        32    193.62.192.6   202.6.241.101
# 8        0x0800    280.0        32  137.189.133.62    123.136.64.7
# 9        0x0800    919.0        43  216.58.203.234  192.122.131.36
#
#    IP_protocol ip_tos  ip_ttl  src_port  dst_port tcp_flags  packet_size  \
# 0           50   0x00     245       0.0         0      0x00         1518
# 1           50   0x00     245       0.0         0      0x00         1518
# 2           50   0x00     245       0.0         0      0x00         1518
# 3           50   0x00     245       0.0         0      0x00         1518
# 4           50   0x00     245       0.0         0      0x00         1518
# 5           50   0x00     245       0.0         0      0x00         1518
# 6            6   0x00      61    5614.0     44476      0x10           74
# 7           17   0x00      54   33001.0     45512      0x10         1514
# 8            6   0x00      58    6270.0     41467      0x10         1422
# 9            6   0x00      60     443.0      4920      0x10           58
#
#    IP_size  sampling_rate
# 0     1496           2048
# 1     1496           2048
# 2     1496           2048
# 3     1496           2048
# 4     1496           2048
# 5     1496           2048
# 6       52           2048
# 7     1492           2048
# 8     1400           2048
# 9       40           2048

# %% [markdown]
# ### Top 5 Talkers

# %%
src_ip_count_map = dict(traffic_df.src_IP.value_counts())
top_talkers = list(src_ip_count_map.items())[:n]

headers = ['Organization', 'IP Address', '# Packet']

print(f'{headers[0]:50} {headers[1]:20} {headers[2]:8}')
print('-' * 80)

for talker in top_talkers:
    talker_ip, talker_count = talker
    res = requests.get(f'{ip_api_url}/{talker[0]}')
    org = res.json()['org']
    print(f'{org:50} {talker_ip:20} {talker_count:>8}')
# Out:
# Organization                                       IP Address           # Packet
# --------------------------------------------------------------------------------
# Duke University                                    152.3.219.19              126
# Internet Archive                                   207.241.228.157            66
# National Library of Medicine                       130.14.250.13              63
# European Bioinformatics Institute                  193.62.192.8               46
# A*STAR                                             192.122.131.36             40

# %% [markdown]
# ### Top 5 Listeners

# %%
dst_ip_count_map = dict(traffic_df.dst_IP.value_counts())
top_listeners = list(dst_ip_count_map.items())[:n]

headers = ['Organization', 'IP Address', '# Packet']

print(f'{headers[0]:50} {headers[1]:20} {headers[2]:8}')
print('-' * 80)

for listener in top_listeners:
    listener_ip, listener_count = listener
    res = requests.get(f'{ip_api_url}/{listener[0]}')
    org = res.json()['org']
    print(f'{org:50} {listener_ip:20} {listener_count:>8}')
# Out:
# Organization                                       IP Address           # Packet
# --------------------------------------------------------------------------------
# Internet2                                          198.71.44.98              126
# A*STAR                                             103.37.198.100             98
# International Islamic University Of Malaysia       210.48.222.9               66
# National University of Singapore                   137.132.228.15             50
# Rpnet                                              202.21.159.244             38

# %% [markdown]
# ### Transport Protocol (Proportion of TCP/UDP)

# %%
ip_protocol_map = {0: 'HOPOPT', 1: 'ICMP', 6: 'TCP', 17: 'UDP', 41: 'IPV6', 47: 'GRE', 50: 'ESP'}
ip_protocols = dict(traffic_df.IP_protocol.value_counts())
ip_protocols = list(ip_protocols.items())

headers = ['IP Protocol', 'Header Value', '# Packet', 'Percentage']
print(f'{headers[0]:15} {headers[1]:15} {headers[2]:12} {headers[3]:9}')
print('-' * 55)

for protocol in ip_protocols:
    protocol_id, count = protocol
    try:
        protocol_name = ip_protocol_map[protocol_id]
    except:
        protocol_name = 'Unknown'
    print(f'{protocol_name:15} {protocol_id:<15} {count:<12} {(count/total_rows) * 100:>9.2f}%')
# Out:
# IP Protocol     Header Value    # Packet     Percentage
# -------------------------------------------------------
# TCP             6               879              73.25%
# ESP             50              140              11.67%
# UDP             17              135              11.25%
# HOPOPT          0               28                2.33%
# GRE             47              14                1.17%
# IPV6            41              2                 0.17%
# Unknown         381             1                 0.08%
# ICMP            1               1                 0.08%

# %% [markdown]
# ### Top 5 Application Protocols

# %%
# Well-known ports range from 0 through 1023.
# Registered ports are 1024 to 49151.
# Dynamic ports (also called private ports) are 49152 to 65535.
# Will need to ask the lab assistant about some of these ports, service names cant be found
# e.g 0, 43930, 56512?
# https://www.iana.org/assignments/service-names-port-numbers/service-names-port-numbers.xhtml?search=0&page=1

# Prof Mo Li:
# Refer to this: https://www.adminsub.net/tcp-udp-port-finder

app_ports = dict(traffic_df.dst_port.value_counts())
# Can print app_ports to show if need debug
app_ports = list(app_ports.items())[:5]

app_port_map = {0: 'Reserved Port', 443: 'HTTPS', 80: 'HTTP', 43930: 'Unassigned', 56152: 'Dynamic/Private'}

headers = ['Service Name', 'Port No.', '# Packet']
print(f'{headers[0]:20} {headers[1]:15} {headers[2]:12}')
print('-' * 45)

for port in app_ports:
    port_no, count = port
    try:
        service_name = app_port_map[port_no]
    except:
        service_name = 'Unknown'
    print(f'{service_name:20} {port_no:<15} {count:<12}')
# Out:
# Service Name         Port No.        # Packet
# ---------------------------------------------
# HTTPS                443             234
# Reserved Port        0               82
# Dynamic/Private      56152           82
# Unassigned           43930           45
# HTTP                 80              37

# %% [markdown]
# ### Traffic Intensity

# %%
# Assuming packet_size is in bytes
total_traffic = sum(list(traffic_df.packet_size))
total_traffic_mb = total_traffic / math.pow(10, 6)

print(f'Total traffic from dataset: {total_traffic_mb:.2f} MB ({total_traffic} bytes)')
# Out:
# Total traffic from dataset: 828.19 MB (828193792 bytes)

# %% [markdown]
# ### Top 5 Communication Pairs

# %%
# Am conducting this analysis via source and destination IP addresses
communication_pairs = dict(traffic_df.groupby(['src_IP', 'dst_IP']).size().sort_values(ascending=False))
communication_pairs = list(communication_pairs.items())[:n]

headers = ['Source IP', 'Dest. IP', 'Count']
print(f'{headers[0]:20} {headers[1]:20} {headers[2]:5}')
print('-' * 50)

for pair in communication_pairs:
    src_dst_ip, count = pair
    src_ip, dst_ip = src_dst_ip
    
    print(f'{src_ip:20} {dst_ip:20} {count:<5}')
# Out:
# Source IP            Dest. IP             Count
# --------------------------------------------------
# 152.3.219.19         198.71.44.98         126
# 207.241.228.157      210.48.222.9         66
# 130.14.250.13        103.37.198.100       63
# 193.62.192.8         137.132.228.15       46
# 130.14.250.11        103.37.198.100       35

# %% [markdown]
# ### Visualizing Network Communication between IP Hosts

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

communication_pairs = dict(traffic_df.groupby(['src_IP', 'dst_IP']).size().sort_values(ascending=False))
communication_pairs = list(communication_pairs.items())
communication_pairs = [x[0] for x in communication_pairs]

G = nx.Graph(communication_pairs)

fig, ax = plt.subplots(1, 1, figsize=(40, 40));
pos = nx.spring_layout(G, k=1/np.sqrt(len(G.nodes())), iterations=20)

plt.title('Visualization of Communication between IP Hosts', fontsize=30, pad=20)
nx.draw_networkx(G, pos=pos, node_size=60, font_size=8, edge_color='red')
plt.savefig("../communication_visualization.png", format="PNG")
